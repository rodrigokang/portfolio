# %% [markdown]
# # Predicting Customer Churn in a Non-Contractual Retail Setting
#
# **AUTHOR**
# Rodrigo Kang

# %% [markdown]
# ## Overview

# %% [markdown]
# This notebook accompanies the project **Predicting Customer Churn in a Non-Contractual Retail Setting** and provides the computational implementation supporting the analyses presented in the portfolio chapter.
#
# The focus is on data preparation, feature engineering, predictive modeling, BG/NBD customer-base analysis, model validation, and performance evaluation. The accompanying chapter discusses the business context, methodological decisions, assumptions, and interpretation of results.

# %% [markdown]
# ## Libraries and Configuration

# %% [markdown]
# The analysis relies on standard Python libraries for data manipulation, visualization, machine learning, and customer analytics. General plotting, display, and reproducibility settings are configured before loading the data.

# %%
# Standard library
from pathlib import Path
import warnings

# Data manipulation
import numpy as np
import pandas as pd

# Database connection
from sqlalchemy import create_engine

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    RocCurveDisplay,
    PrecisionRecallDisplay,
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Display options
pd.set_option("display.max_columns", 100)
pd.set_option("display.float_format", "{:,.4f}".format)

# Plot style
sns.set_theme(style="whitegrid")

# Warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Database Connection

# %% [markdown]
# The AdventureWorks database is used as the source of customer and transaction data. A PostgreSQL connection is established to extract the information required for churn modeling and customer retention analysis.

# %%
from local_config import DB_USER, DB_PASSWORD
from sqlalchemy.engine import URL
from sqlalchemy import create_engine

# %%
db_user = DB_USER
db_password = DB_PASSWORD

# %%
connection_url = URL.create(
    drivername="postgresql+psycopg2",
    username=db_user,
    password=db_password,
    host="localhost",
    port=5432,
    database="adventureworks",
)

engine = create_engine(connection_url)

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# The transaction history is extracted at the order level. Keeping the data at this level preserves the temporal structure needed to define calibration and validation windows, build customer-level features, and construct the churn target without using future information.

# %%
query = """
SELECT
    c.customerid,
    CASE
        WHEN c.personid IS NOT NULL THEN 'Individual'
        WHEN c.storeid IS NOT NULL THEN 'Store'
        ELSE 'Unknown'
    END AS customer_type,
    soh.salesorderid,
    soh.orderdate,
    soh.totaldue,
    st.name AS territory
FROM sales.customer AS c
JOIN sales.salesorderheader AS soh
    ON c.customerid = soh.customerid
LEFT JOIN sales.salesterritory AS st
    ON soh.territoryid = st.territoryid
WHERE soh.status = 5
ORDER BY
    c.customerid,
    soh.orderdate,
    soh.salesorderid
"""

transactions = pd.read_sql(query, engine)

transactions.head()
# Out:
#    customerid customer_type  salesorderid  orderdate   totaldue  territory
# 0       11000    Individual         43793 2022-06-20 3,756.9890  Australia
# 1       11000    Individual         51522 2024-06-19 2,587.8769  Australia
# 2       11000    Individual         57418 2024-10-02 2,770.2682  Australia
# 3       11001    Individual         43767 2022-06-16 3,729.3640  Australia
# 4       11001    Individual         51493 2024-06-17 2,674.0227  Australia

# %% [markdown]
# ## Initial Data Inspection

# %% [markdown]
# Before constructing churn labels and predictive features, it is useful to inspect the size, structure, and temporal coverage of the transaction history. These checks help determine appropriate calibration and validation periods for the analysis.

# %%
print(f"Number of transactions: {len(transactions):,}")
print(f"Number of customers: {transactions['customerid'].nunique():,}")

print("\nCustomer types:")
print(transactions["customer_type"].value_counts())

print("\nDate range:")
print(f"Start: {transactions['orderdate'].min()}")
print(f"End:   {transactions['orderdate'].max()}")
# Out:
# Number of transactions: 31,465
# Number of customers: 19,119
#
# Customer types:
# customer_type
# Individual    31465
# Name: count, dtype: int64
#
# Date range:
# Start: 2022-05-30 00:00:00
# End:   2025-06-29 00:00:00

# %%
transactions["orderdate"] = pd.to_datetime(
    transactions["orderdate"]
)

transactions["year"] = (
    transactions["orderdate"]
    .dt.year
)

transactions["month"] = (
    transactions["orderdate"]
    .dt.to_period("M")
)

# %%
annual_summary = (
    transactions
    .groupby("year")
    .agg(
        orders=("salesorderid", "nunique"),
        customers=("customerid", "nunique"),
        revenue=("totaldue", "sum")
    )
)

annual_summary
# Out:
#       orders  customers         revenue
# year
# 2022    1692       1412 16,316,694.1690
# 2023    3830       3155 35,514,705.6680
# 2024   14244      11145 49,020,486.5120
# 2025   11699      10303 22,364,899.7669

# %% [markdown]
# The following figure summarizes the evolution of order activity throughout the observation period.

# %%
monthly_orders = (
    transactions
    .groupby("month")
    .agg(
        orders=("salesorderid", "nunique")
    )
    .reset_index()
)

monthly_orders["month"] = (
    monthly_orders["month"]
    .astype(str)
)

fig, ax = plt.subplots(figsize=(12, 5))

sns.lineplot(
    data=monthly_orders,
    x="month",
    y="orders",
    ax=ax
)

ax.set_title(
    "Monthly Order Volume"
)

ax.set_xlabel("")
ax.set_ylabel("Orders")

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Calibration and Validation Periods

# %% [markdown]
# Customer features are constructed using a calibration period ending on June 30, 2024. Customer activity during the subsequent twelve-month validation period is used to determine whether each customer remained active or became inactive.
#
# This temporal split ensures that all predictive variables are calculated using information available at the time the prediction would have been made.

# %%
calibration_end = pd.Timestamp("2024-06-30")
validation_end = pd.Timestamp("2025-06-29")

print(f"Calibration end: {calibration_end.date()}")
print(f"Validation end:  {validation_end.date()}")
# Out:
# Calibration end: 2024-06-30
# Validation end:  2025-06-29

# %% [markdown]
# ## Transaction Data Partitioning

# %% [markdown]
# The transaction history is divided into calibration and validation datasets using the cutoff date defined above. Customer features are computed exclusively from calibration-period transactions, while customer activity during the validation period is used to construct the churn outcome.

# %%
calibration_transactions = (
    transactions.loc[
        transactions["orderdate"] <= calibration_end
    ]
    .copy()
)

validation_transactions = (
    transactions.loc[
        (transactions["orderdate"] > calibration_end)
        &
        (transactions["orderdate"] <= validation_end)
    ]
    .copy()
)

print(
    f"Calibration transactions: "
    f"{len(calibration_transactions):,}"
)

print(
    f"Validation transactions: "
    f"{len(validation_transactions):,}"
)
# Out:
# Calibration transactions: 8,306
# Validation transactions: 23,159

# %%
print(
    f"Calibration period: "
    f"{calibration_transactions['orderdate'].min().date()} "
    f"to "
    f"{calibration_transactions['orderdate'].max().date()}"
)

print(
    f"Validation period: "
    f"{validation_transactions['orderdate'].min().date()} "
    f"to "
    f"{validation_transactions['orderdate'].max().date()}"
)
# Out:
# Calibration period: 2022-05-30 to 2024-06-30
# Validation period: 2024-07-01 to 2025-06-29

# %% [markdown]
# ## Customer Cohort Definition

# %% [markdown]
# The modeling cohort consists of customers with at least one transaction during the calibration period. Features and churn outcomes are defined relative to this cohort.

# %%
customer_cohort = pd.DataFrame({
    "customerid":
        calibration_transactions["customerid"]
        .unique()
})

print(
    f"Customers in calibration cohort: "
    f"{len(customer_cohort):,}"
)
# Out:
# Customers in calibration cohort: 6,243

# %%
validation_customers = set(
    validation_transactions["customerid"]
)

calibration_customers = set(
    calibration_transactions["customerid"]
)

new_customers = (
    validation_customers
    - calibration_customers
)

print(
    f"Customers observed in validation: "
    f"{len(validation_customers):,}"
)

print(
    f"New customers appearing only in validation: "
    f"{len(new_customers):,}"
)
# Out:
# Customers observed in validation: 18,044
# New customers appearing only in validation: 12,876

# %% [markdown]
# ## RFM Feature Construction

# %% [markdown]
# Customer-level RFM features are computed using transactions observed during the calibration period only.
#
# Recency is defined as the number of days since the customer's most recent purchase before the calibration cutoff date. Frequency corresponds to the number of orders placed during the calibration period, while Monetary represents the cumulative revenue generated by the customer over the same period.

# %%
reference_date = calibration_end

print(
    f"Reference date: "
    f"{reference_date.date()}"
)
# Out:
# Reference date: 2024-06-30

# %% [markdown]
# ### Recency

# %%
recency = (
    calibration_transactions
    .groupby("customerid")
    .agg(
        last_purchase=("orderdate", "max")
    )
    .reset_index()
)

recency["recency"] = (
    reference_date
    - recency["last_purchase"]
).dt.days

recency.head()
# Out:
#    customerid last_purchase  recency
# 0       11000    2024-06-19       11
# 1       11001    2024-06-17       13
# 2       11002    2024-06-01       29
# 3       11003    2024-06-06       24
# 4       11004    2024-06-23        7

# %% [markdown]
# ### Frequency

# %%
frequency = (
    calibration_transactions
    .groupby("customerid")
    .agg(
        frequency=("salesorderid", "nunique")
    )
    .reset_index()
)

frequency.head()
# Out:
#    customerid  frequency
# 0       11000          2
# 1       11001          2
# 2       11002          2
# 3       11003          2
# 4       11004          2

# %% [markdown]
# ### Monetary

# %%
monetary = (
    calibration_transactions
    .groupby("customerid")
    .agg(
        monetary=("totaldue", "sum")
    )
    .reset_index()
)

monetary.head()
# Out:
#    customerid   monetary
# 0       11000 6,344.8659
# 1       11001 6,403.3867
# 2       11002 6,292.9530
# 3       11003 6,319.4398
# 4       11004 6,383.5298

# %% [markdown]
# ### RFM Dataset

# %%
rfm = (
    customer_cohort
    .merge(
        recency[["customerid", "recency"]],
        on="customerid",
        how="left"
    )
    .merge(
        frequency,
        on="customerid",
        how="left"
    )
    .merge(
        monetary,
        on="customerid",
        how="left"
    )
)

rfm.head()
# Out:
#    customerid  recency  frequency   monetary
# 0       11000       11          2 6,344.8659
# 1       11001       13          2 6,403.3867
# 2       11002       29          2 6,292.9530
# 3       11003       24          2 6,319.4398
# 4       11004        7          2 6,383.5298

# %%
rfm.describe().T
# Out:
#                 count        mean         std         min         25%  \
# customerid 6,243.0000 19,964.7426  6,183.8489 11,000.0000 14,334.5000
# recency    6,243.0000    293.0284    221.9533      0.0000     89.0000
# frequency  6,243.0000      1.3305      1.1790      1.0000      1.0000
# monetary   6,243.0000 11,668.7065 53,264.9907      1.5183  2,264.2536
#
#                    50%         75%          max
# customerid 19,160.0000 26,113.5000  30,118.0000
# recency       258.0000    465.0000     762.0000
# frequency       1.0000      1.0000       9.0000
# monetary    2,410.6266  3,953.9884 721,813.8295

# %% [markdown]
# The calibration-period RFM variables exhibit substantial heterogeneity across customers. Most customers placed a single order during the calibration period, while a relatively small number of customers generated multiple purchases and substantially higher revenue.
#
# The Monetary variable is particularly skewed, with a median value considerably lower than its mean, indicating the presence of a small group of high-spending customers. These characteristics are typical of transactional retail data and motivate the use of both machine learning and probabilistic customer-base models in the subsequent analysis.

# %% [markdown]
# ## Churn Target Construction

# %% [markdown]
# In a non-contractual retail setting, customer churn is not directly observable because customers are free to purchase at any time without formally terminating their relationship with the company.
#
# For this analysis, a customer is considered inactive if the time elapsed since their most recent observed purchase exceeds 365 days at the end of the validation period. This operational definition provides a practical benchmark for supervised churn modeling while remaining consistent with the notion of customer inactivity used in the customer-base analysis literature.

# %%
customer_activity = (
    transactions.loc[
        transactions["customerid"].isin(
            customer_cohort["customerid"]
        )
    ]
    .groupby("customerid")
    .agg(
        last_purchase=("orderdate", "max")
    )
    .reset_index()
)

customer_activity.head()
# Out:
#    customerid last_purchase
# 0       11000    2024-10-02
# 1       11001    2025-05-11
# 2       11002    2024-07-25
# 3       11003    2024-10-09
# 4       11004    2024-09-30

# %% [markdown]
# ### Future Recency

# %%
customer_activity["future_recency"] = (
    validation_end
    - customer_activity["last_purchase"]
).dt.days

customer_activity.head()
# Out:
#    customerid last_purchase  future_recency
# 0       11000    2024-10-02             270
# 1       11001    2025-05-11              49
# 2       11002    2024-07-25             339
# 3       11003    2024-10-09             263
# 4       11004    2024-09-30             272

# %%
customer_activity["future_recency"].describe()
# Out:
# count   6,243.0000
# mean      235.6984
# std       211.5365
# min         0.0000
# 25%        92.0000
# 50%       177.0000
# 75%       302.0000
# max     1,126.0000
# Name: future_recency, dtype: float64

# %% [markdown]
# ### Churn Definition

# %%
customer_activity["churn"] = (
    customer_activity["future_recency"] > 365
).astype(int)

customer_activity["churn"].value_counts()
# Out:
# churn
# 0    5227
# 1    1016
# Name: count, dtype: int64

# %%
churn_rate = (
    customer_activity["churn"]
    .mean()
)

print(
    f"Churn rate: "
    f"{churn_rate:.2%}"
)
# Out:
# Churn rate: 16.27%

# %% [markdown]
# The resulting churn rate provides an indication of the proportion of customers who became inactive during the observation period according to the operational definition adopted in this study.

# %% [markdown]
# ## Churn Target Diagnostics

# %% [markdown]
# Approximately sixteen percent of customers are classified as inactive at the end of the validation period according to the adopted definition.
#
# The resulting class distribution remains sufficiently balanced for supervised learning, allowing standard classification algorithms to be trained without requiring aggressive resampling procedures. At the same time, the presence of a meaningful inactive segment provides a realistic setting for evaluating customer retention models.

# %% [markdown]
# ## Modeling Dataset

# %% [markdown]
# The customer-level predictive features are merged with the churn outcome to create the final dataset used for supervised learning and customer retention analysis.

# %%
model_data = (
    rfm
    .merge(
        customer_activity[
            ["customerid", "future_recency", "churn"]
        ],
        on="customerid",
        how="left"
    )
)

model_data.head()
# Out:
#    customerid  recency  frequency   monetary  future_recency  churn
# 0       11000       11          2 6,344.8659             270      0
# 1       11001       13          2 6,403.3867              49      0
# 2       11002       29          2 6,292.9530             339      0
# 3       11003       24          2 6,319.4398             263      0
# 4       11004        7          2 6,383.5298             272      0

# %%
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6243 entries, 0 to 6242
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      6243 non-null   int64
#  1   recency         6243 non-null   int64
#  2   frequency       6243 non-null   int64
#  3   monetary        6243 non-null   float64
#  4   future_recency  6243 non-null   int64
#  5   churn           6243 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 292.8 KB

# %%
model_data["churn"].value_counts(
    normalize=True
)
# Out:
# churn
# 0   0.8373
# 1   0.1627
# Name: proportion, dtype: float64

# %% [markdown]
# ## Relationship Between RFM Features and Churn

# %% [markdown]
# Before fitting predictive models, it is useful to examine how the RFM variables differ between active and inactive customers. These comparisons provide an initial indication of the predictive signal contained in the customer transaction history.

# %%
plot_data = model_data.copy()

plot_data["log_monetary"] = np.log1p(
    plot_data["monetary"]
)

fig, axes = plt.subplots(
    nrows=1,
    ncols=3,
    figsize=(15, 5)
)

sns.boxplot(
    data=plot_data,
    x="churn",
    y="recency",
    ax=axes[0]
)

axes[0].set_title("Recency vs Churn")
axes[0].set_xlabel("Churn")
axes[0].set_ylabel("Recency (days)")

sns.boxplot(
    data=plot_data,
    x="churn",
    y="frequency",
    ax=axes[1]
)

axes[1].set_title("Frequency vs Churn")
axes[1].set_xlabel("Churn")
axes[1].set_ylabel("Frequency")

sns.boxplot(
    data=plot_data,
    x="churn",
    y="log_monetary",
    ax=axes[2]
)

axes[2].set_title("Log Monetary vs Churn")
axes[2].set_xlabel("Churn")
axes[2].set_ylabel("Log Monetary")

plt.tight_layout()

plt.show()

# %%
rfm_churn_summary = (
    model_data
    .groupby("churn")
    .agg(
        customers=("customerid", "count"),
        recency_median=("recency", "median"),
        frequency_median=("frequency", "median"),
        monetary_median=("monetary", "median")
    )
)

rfm_churn_summary
# Out:
#        customers  recency_median  frequency_median  monetary_median
# churn
# 0           5227        276.0000            1.0000       2,410.6266
# 1           1016        123.0000            1.0000       2,872.4577

# %% [markdown]
# The exploratory analysis suggests that the RFM variables contain information related to future customer inactivity. While differences between active and inactive customers are observable, the relationships are not sufficiently clear to support simple rule-based classification.
#
# These findings motivate the use of supervised learning models to quantify the predictive value of the RFM variables and compare their performance with probabilistic customer-base approaches such as BG/NBD.

# %% [markdown]
# ## Modeling Strategy

# %% [markdown]
# The objective is to evaluate both classification algorithms and class-balancing strategies for customer churn prediction.
#
# Because inactive customers represent a minority of the customer base, several resampling techniques are considered. Each resampling strategy is combined with multiple classification algorithms and evaluated using a common set of performance metrics.
#
# The best-performing model is selected for detailed diagnostic analysis and subsequently compared with a probabilistic customer-base model based on the BG/NBD framework.

# %% [markdown]
# ## Train-Test Split

# %% [markdown]
# The customer-level dataset is divided into training and testing subsets to evaluate model performance on unseen observations.
#
# A stratified split is used to preserve the proportion of active and inactive customers in both subsets.

# %%
X = model_data[
    ["recency", "frequency", "monetary"]
]

y = model_data["churn"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print(
    f"Training observations: "
    f"{len(X_train):,}"
)

print(
    f"Testing observations: "
    f"{len(X_test):,}"
)

print(
    f"Training churn rate: "
    f"{y_train.mean():.2%}"
)

print(
    f"Testing churn rate: "
    f"{y_test.mean():.2%}"
)
# Out:
# Training observations: 4,994
# Testing observations: 1,249
# Training churn rate: 16.28%
# Testing churn rate: 16.25%

# %% [markdown]
# ## Benchmark Configuration

# %% [markdown]
# The benchmark combines four class-balancing strategies with three classification algorithms. Each model is evaluated using the same training and testing partitions to ensure a fair comparison across methodologies.

# %%
resampling_strategies = {
    "Original": None,
    "Random Undersampling": RandomUnderSampler(
        random_state=42
    ),
    "Random Oversampling": RandomOverSampler(
        random_state=42
    ),
    "SMOTE": SMOTE(
        random_state=42
    )
}

# %%
models = {
    "Logistic Regression": LogisticRegression(
        max_iter=1000,
        random_state=42
    ),
    "Random Forest": RandomForestClassifier(
        n_estimators=300,
        random_state=42,
        n_jobs=-1
    ),
    "XGBoost": XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=3,
        subsample=0.8,
        colsample_bytree=0.8,
        eval_metric="logloss",
        random_state=42
    )
}

# %%
def evaluate_classifier(
    model_name,
    resampling_name,
    pipeline,
    X_train,
    y_train,
    X_test,
    y_test
):
    """
    Evaluate a classification model using a fixed
    training and testing partition.

    Input
    -----
    model_name : str
        Name of the classification algorithm.

    resampling_name : str
        Name of the resampling strategy.

    pipeline : imblearn.pipeline.Pipeline
        Modeling pipeline including preprocessing,
        optional resampling, and classifier.

    X_train : pandas.DataFrame
        Training predictors.

    y_train : pandas.Series
        Training target variable.

    X_test : pandas.DataFrame
        Testing predictors.

    y_test : pandas.Series
        Testing target variable.

    Output
    ------
    dict
        Dictionary containing performance metrics
        and the fitted pipeline.

    Author
    ------
    Rodrigo Kang
    """

    pipeline.fit(
        X_train,
        y_train
    )

    y_pred = pipeline.predict(
        X_test
    )

    y_prob = pipeline.predict_proba(
        X_test
    )[:, 1]

    return {
        "model": model_name,
        "resampling": resampling_name,
        "accuracy": accuracy_score(
            y_test,
            y_pred
        ),
        "precision": precision_score(
            y_test,
            y_pred
        ),
        "recall": recall_score(
            y_test,
            y_pred
        ),
        "f1_score": f1_score(
            y_test,
            y_pred
        ),
        "roc_auc": roc_auc_score(
            y_test,
            y_prob
        ),
        "pr_auc": average_precision_score(
            y_test,
            y_prob
        ),
        "pipeline": pipeline
    }

# %% [markdown]
# ## Benchmark Execution

# %% [markdown]
# Each classifier is combined with each resampling strategy and evaluated on the same holdout dataset.
#
# Resampling is applied exclusively to the training data through the modeling pipeline, preventing information leakage from the test set.

# %%
benchmark_results = []

for resampling_name, sampler in (
    resampling_strategies.items()
):

    for model_name, model in (
        models.items()
    ):

        steps = [
            (
                "scaler",
                StandardScaler()
            )
        ]

        if sampler is not None:

            steps.append(
                (
                    "sampler",
                    sampler
                )
            )

        steps.append(
            (
                "model",
                model
            )
        )

        pipeline = ImbPipeline(
            steps=steps
        )

        result = evaluate_classifier(
            model_name=model_name,
            resampling_name=resampling_name,
            pipeline=pipeline,
            X_train=X_train,
            y_train=y_train,
            X_test=X_test,
            y_test=y_test
        )

        benchmark_results.append(
            result
        )

# %%
benchmark_table = (
    pd.DataFrame(
        benchmark_results
    )
    .drop(
        columns="pipeline"
    )
    .sort_values(
        by=[
            "pr_auc",
            "f1_score",
            "roc_auc"
        ],
        ascending=False
    )
    .reset_index(
        drop=True
    )
)

benchmark_table
# Out:
#                   model            resampling  accuracy  precision  recall  \
# 0               XGBoost              Original    0.8975     0.8261  0.4680
# 1               XGBoost                 SMOTE    0.8359     0.4965  0.6946
# 2               XGBoost   Random Oversampling    0.7678     0.3921  0.7783
# 3               XGBoost  Random Undersampling    0.7750     0.3995  0.7635
# 4         Random Forest              Original    0.8623     0.5987  0.4631
# 5         Random Forest                 SMOTE    0.8287     0.4749  0.5123
# 6         Random Forest  Random Undersampling    0.7158     0.3333  0.7488
# 7         Random Forest   Random Oversampling    0.7926     0.4041  0.5813
# 8   Logistic Regression                 SMOTE    0.6701     0.2703  0.6059
# 9   Logistic Regression  Random Undersampling    0.6333     0.2505  0.6305
# 10  Logistic Regression   Random Oversampling    0.6517     0.2593  0.6158
# ...

# %% [markdown]
# The benchmark results are ranked primarily according to Precision-Recall AUC, which is particularly informative for imbalanced classification problems. F1 score and ROC-AUC are used as secondary criteria when comparing competing models.

# %% [markdown]
# ## Best Model Selection

# %% [markdown]
# Among all evaluated combinations, XGBoost trained on the original dataset achieved the highest Precision-Recall AUC while maintaining the strongest overall balance between precision and recall.
#
# Although resampling strategies increased recall, they did so at the expense of precision and did not materially improve overall ranking performance. Consequently, the original XGBoost model is selected for detailed diagnostic analysis and comparison with the BG/NBD benchmark.

# %%
best_model_row = max(
    benchmark_results,
    key=lambda x: (
        x["pr_auc"],
        x["f1_score"],
        x["roc_auc"]
    )
)

best_pipeline = best_model_row["pipeline"]

best_model_summary = pd.DataFrame({
    "Model": [best_model_row["model"]],
    "Resampling": [best_model_row["resampling"]],
    "Accuracy": [best_model_row["accuracy"]],
    "Precision": [best_model_row["precision"]],
    "Recall": [best_model_row["recall"]],
    "F1 Score": [best_model_row["f1_score"]],
    "ROC-AUC": [best_model_row["roc_auc"]],
    "PR-AUC": [best_model_row["pr_auc"]]
})

best_model_summary
# Out:
#      Model Resampling  Accuracy  Precision  Recall  F1 Score  ROC-AUC  PR-AUC
# 0  XGBoost   Original    0.8975     0.8261  0.4680    0.5975   0.8535  0.6701

# %% [markdown]
# ## Best Model Diagnostics

# %% [markdown]
# The selected XGBoost model is examined in greater detail to better understand its predictive behavior and discriminative performance.
#
# Several diagnostic tools are considered, including the confusion matrix, ROC curve, Precision-Recall curve, Kolmogorov-Smirnov statistic, and feature importance analysis.

# %%
y_pred_best = best_pipeline.predict(
    X_test
)

y_prob_best = best_pipeline.predict_proba(
    X_test
)[:, 1]

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# The confusion matrix summarizes the classification outcomes obtained on the testing dataset and highlights the trade-off between correctly identifying inactive customers and avoiding false alarms.

# %%
cm = confusion_matrix(
    y_test,
    y_pred_best
)

fig, ax = plt.subplots(
    figsize=(6, 5)
)

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    ax=ax
)

ax.set_title(
    "Confusion Matrix"
)

ax.set_xlabel(
    "Predicted Class"
)

ax.set_ylabel(
    "Observed Class"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Receiver Operating Characteristic Curve

# %% [markdown]
# The ROC curve evaluates the model's ability to distinguish between active and inactive customers across a range of classification thresholds.

# %%
fig, ax = plt.subplots(
    figsize=(6, 5)
)

RocCurveDisplay.from_predictions(
    y_test,
    y_prob_best,
    ax=ax
)

ax.set_title(
    "ROC Curve"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Precision-Recall Curve

# %% [markdown]
# Because inactive customers represent a minority of the customer base, the Precision-Recall curve provides a particularly informative assessment of ranking performance.

# %%
fig, ax = plt.subplots(
    figsize=(6, 5)
)

PrecisionRecallDisplay.from_predictions(
    y_test,
    y_prob_best,
    ax=ax
)

ax.set_title(
    "Precision-Recall Curve"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Kolmogorov-Smirnov Statistic

# %% [markdown]
# The Kolmogorov-Smirnov (KS) statistic measures the maximum separation between the cumulative distributions of churners and non-churners.
#
# In customer analytics and credit risk applications, the KS statistic is commonly used to evaluate the discriminatory power of predictive models.

# %%
ks_data = pd.DataFrame({
    "actual": y_test,
    "score": y_prob_best
})

ks_data["non_churn"] = (
    ks_data["actual"] == 0
).astype(int)

ks_data["churn"] = (
    ks_data["actual"] == 1
).astype(int)

ks_data["bucket"] = pd.qcut(
    ks_data["score"],
    q=100,
    duplicates="drop"
)

ks_table = (
    ks_data
    .groupby("bucket", observed=True)
    .agg(
        churn=("churn", "sum"),
        non_churn=("non_churn", "sum")
    )
    .sort_index(
        ascending=False
    )
)

ks_table["cum_churn"] = (
    ks_table["churn"]
    .cumsum()
    /
    ks_table["churn"].sum()
)

ks_table["cum_non_churn"] = (
    ks_table["non_churn"]
    .cumsum()
    /
    ks_table["non_churn"].sum()
)

ks_table["ks"] = (
    ks_table["cum_churn"]
    -
    ks_table["cum_non_churn"]
).abs()

ks_statistic = ks_table["ks"].max()

ks_plot = ks_table.reset_index(
    drop=True
)

ks_plot["percentile"] = np.arange(
    1,
    len(ks_plot) + 1
)

ks_max_idx = ks_plot["ks"].idxmax()

ks_x = ks_plot.loc[
    ks_max_idx,
    "percentile"
]

ks_churn = ks_plot.loc[
    ks_max_idx,
    "cum_churn"
]

ks_non_churn = ks_plot.loc[
    ks_max_idx,
    "cum_non_churn"
]

fig, ax = plt.subplots(
    figsize=(8, 5)
)

ax.plot(
    ks_plot["percentile"],
    ks_plot["cum_churn"],
    label="Churn"
)

ax.plot(
    ks_plot["percentile"],
    ks_plot["cum_non_churn"],
    label="Non-Churn"
)

ax.vlines(
    ks_x,
    ks_non_churn,
    ks_churn,
    linestyles="--"
)

ax.set_title(
    f"KS Curve (KS = {ks_statistic:.3f})"
)

ax.set_xlabel(
    "Score Percentile"
)

ax.set_ylabel(
    "Cumulative Distribution"
)

ax.legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# The KS statistic of approximately 0.56 indicates strong separation between churners and non-churners. The selected XGBoost model successfully concentrates a large proportion of inactive customers among the highest predicted risk scores, confirming its usefulness as a customer retention prioritization tool.

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# Feature importance scores provide insight into the relative contribution of each RFM variable to the predictive performance of the selected XGBoost model.

# %%
feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": (
        best_pipeline.named_steps["model"]
        .feature_importances_
    )
})

feature_importance = (
    feature_importance
    .sort_values(
        "Importance",
        ascending=False
    )
)

feature_importance
# Out:
#      Feature  Importance
# 0    recency      0.3630
# 2   monetary      0.3203
# 1  frequency      0.3167

# %%
fig, ax = plt.subplots(
    figsize=(8, 5)
)

sns.barplot(
    data=feature_importance,
    x="Importance",
    y="Feature",
    ax=ax
)

ax.set_title(
    "XGBoost Feature Importance"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# The feature importance analysis indicates that all three RFM variables contribute meaningfully to the predictive performance of the model.
#
# Although Recency emerges as the most influential predictor, Frequency and Monetary provide comparable explanatory value. This suggests that customer inactivity cannot be explained solely by the time elapsed since the most recent purchase and that both purchasing intensity and spending behavior contain relevant information for churn prediction.
#
# The relatively balanced contribution of the three variables supports the use of the full RFM representation when modeling customer churn in a non-contractual retail setting.

# %% [markdown]
# ## BG/NBD Benchmark

# %% [markdown]
# In addition to machine learning models, a probabilistic customer-base model is evaluated as a benchmark.
#
# The BG/NBD model proposed by Fader, Hardie, and Lee estimates the probability that a customer remains active based exclusively on the timing and frequency of historical transactions. Unlike supervised classification approaches, BG/NBD does not require a predefined churn label and instead models customer activity as a latent stochastic process.

# %%
calibration_transactions = transactions.loc[
    transactions["orderdate"] <= calibration_end
].copy()

# %%
customer_summary = (
    calibration_transactions
    .groupby("customerid")
    .agg(
        first_purchase=("orderdate", "min"),
        last_purchase=("orderdate", "max"),
        frequency=("salesorderid", "count")
    )
    .reset_index()
)

# %%
customer_summary["frequency"] = (
    customer_summary["frequency"] - 1
)

# %%
customer_summary["recency"] = (
    customer_summary["last_purchase"]
    -
    customer_summary["first_purchase"]
).dt.days

# %%
customer_summary["T"] = (
    calibration_end
    -
    customer_summary["first_purchase"]
).dt.days

# %%
customer_summary.head()
# Out:
#    customerid first_purchase last_purchase  frequency  recency    T
# 0       11000     2022-06-20    2024-06-19          1      730  741
# 1       11001     2022-06-16    2024-06-17          1      732  745
# 2       11002     2022-06-08    2024-06-01          1      724  753
# 3       11003     2022-05-30    2024-06-06          1      738  762
# 4       11004     2022-06-24    2024-06-23          1      730  737

# %% [markdown]
# ### BG/NBD Input Variables

# %% [markdown]
# The BG/NBD model requires three customer-level inputs:
#
# - Frequency: number of repeat purchases.
# - Recency: time elapsed between the first and most recent purchase.
# - T: customer age measured from the first purchase to the end of the calibration period.

# %%
customer_summary.columns
# Out:
# Index(['customerid', 'first_purchase', 'last_purchase', 'frequency', 'recency',
#        'T'],
#       dtype='object')

# %%
customer_summary[
    ["frequency", "recency", "T"]
].describe()
# Out:
#        frequency    recency          T
# count 6,243.0000 6,243.0000 6,243.0000
# mean      0.3305    48.7653   341.7937
# std       1.1790   150.8209   220.8385
# min       0.0000     0.0000     0.0000
# 25%       0.0000     0.0000   149.0000
# 50%       0.0000     0.0000   335.0000
# 75%       0.0000     0.0000   522.0000
# max       8.0000   757.0000   762.0000

# %% [markdown]
# ### BG/NBD Calibration Dataset

# %% [markdown]
# The customer-level inputs reveal a highly concentrated purchasing pattern. Most customers made only a single purchase during the calibration period, resulting in zero repeat transactions according to the BG/NBD definition of purchase frequency.
#
# This characteristic is common in many retail environments and represents an important challenge for customer-base models, which must infer future purchasing behavior from limited historical information.

# %%
from lifetimes import BetaGeoFitter

# %% [markdown]
# ### Model Estimation

# %%
bgnbd_input = (
    customer_summary
    .loc[
        customer_summary["T"] > 0,
        ["customerid", "frequency", "recency", "T"]
    ]
    .copy()
)

bgnbd_input[
    ["frequency", "recency", "T"]
].describe()
# Out:
#        frequency    recency          T
# count 6,206.0000 6,206.0000 6,206.0000
# mean      0.3324    49.0561   343.8315
# std       1.1823   151.2227   219.9084
# min       0.0000     0.0000     1.0000
# 25%       0.0000     0.0000   152.0000
# 50%       0.0000     0.0000   335.0000
# 75%       0.0000     0.0000   523.7500
# max       8.0000   757.0000   762.0000

# %%
penalizers = [
    0.01,
    0.05,
    0.10,
    0.50,
    1.00
]

fitted_models = {}

for penalizer in penalizers:

    try:
        bgf = BetaGeoFitter(
            penalizer_coef=penalizer
        )

        bgf.fit(
            bgnbd_input["frequency"],
            bgnbd_input["recency"],
            bgnbd_input["T"]
        )

        fitted_models[penalizer] = bgf

        print(
            f"Converged with penalizer_coef={penalizer}"
        )

        break

    except Exception as error:

        print(
            f"Failed with penalizer_coef={penalizer}: {type(error).__name__}"
        )
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: nan
#         x: [-1.974e+00 -1.459e+00 -3.313e+03 -2.466e+03]
#       nit: 39
#       jac: [       nan        nan        nan        nan]
#  hess_inv: [[ 1.096e+01  1.032e+01 -9.694e+03 -7.227e+03]
#             [ 1.032e+01  1.749e+01 -1.397e+04 -1.041e+04]
#             [-9.694e+03 -1.397e+04  1.916e+08  1.426e+08]
#             [-7.227e+03 -1.041e+04  1.426e+08  1.062e+08]]
#      nfev: 150
#      njev: 150
# Failed with penalizer_coef=0.01: ConvergenceError
# Converged with penalizer_coef=0.05

# %%
bgf = list(
    fitted_models.values()
)[0]

bgf.summary
# Out:
#           coef  se(coef)  lower 95% bound  upper 95% bound
# r       0.1057    0.0056           0.0946           0.1167
# alpha 120.6056    8.1725         104.5875         136.6236
# a       0.0000    0.0000          -0.0000           0.0000
# b       0.0001    0.0284          -0.0555           0.0557

# %% [markdown]
# ### Probability of Remaining Active

# %% [markdown]
# The BG/NBD model estimates the probability that each customer remains active at the end of the calibration period.

# %%
customer_summary["p_alive"] = (
    bgf.conditional_probability_alive(
        customer_summary["frequency"],
        customer_summary["recency"],
        customer_summary["T"]
    )
)

# %%
customer_summary["p_alive"].describe()
# Out:
# count   6,243.0000
# mean        1.0000
# std         0.0000
# min         1.0000
# 25%         1.0000
# 50%         1.0000
# 75%         1.0000
# max         1.0000
# Name: p_alive, dtype: float64

# %%
fig, ax = plt.subplots(
    figsize=(8, 5)
)

sns.histplot(
    customer_summary["p_alive"],
    bins=30,
    kde=True,
    ax=ax
)

ax.set_title(
    "Distribution of Estimated P(Alive)"
)

plt.tight_layout()

plt.show()

# %%
bgnbd_data = (
    model_data[
        ["customerid", "churn"]
    ]
    .merge(
        customer_summary[
            ["customerid", "p_alive"]
        ],
        on="customerid",
        how="inner"
    )
)

# %%
bgnbd_data.head()
# Out:
#    customerid  churn  p_alive
# 0       11000      0   1.0000
# 1       11001      0   1.0000
# 2       11002      0   1.0000
# 3       11003      0   1.0000
# 4       11004      0   1.0000

# %%
bgnbd_data["churn_probability"] = (
    1 -
    bgnbd_data["p_alive"]
)

# %%
bgnbd_roc_auc = roc_auc_score(
    bgnbd_data["churn"],
    bgnbd_data["churn_probability"]
)

bgnbd_pr_auc = average_precision_score(
    bgnbd_data["churn"],
    bgnbd_data["churn_probability"]
)

print(
    f"BG/NBD ROC-AUC: {bgnbd_roc_auc:.4f}"
)

print(
    f"BG/NBD PR-AUC: {bgnbd_pr_auc:.4f}"
)
# Out:
# BG/NBD ROC-AUC: 0.6139
# BG/NBD PR-AUC: 0.2959

# %% [markdown]
# ### BG/NBD Performance

# %% [markdown]
# The BG/NBD model converged only after increasing the regularization parameter and produced highly concentrated estimates of customer survival probabilities.
#
# Most customers received estimated probabilities of remaining active very close to one, resulting in limited discriminatory power when evaluated against the observed churn labels.
#
# This behavior appears to be related to the transactional structure of the AdventureWorks dataset, where the majority of customers completed only a single purchase during the calibration period. Because BG/NBD relies heavily on repeat-purchase behavior to infer latent customer activity, the scarcity of repeated transactions substantially limits its predictive effectiveness in this setting.

# %% [markdown]
# ## Machine Learning vs BG/NBD

# %% [markdown]
# The predictive performance of the selected XGBoost model is compared with the BG/NBD benchmark using the same validation cohort and churn definition.

# %%
comparison_results = pd.DataFrame({
    "Model": [
        "XGBoost",
        "BG/NBD"
    ],
    "ROC-AUC": [
        best_model_row["roc_auc"],
        bgnbd_roc_auc
    ],
    "PR-AUC": [
        best_model_row["pr_auc"],
        bgnbd_pr_auc
    ]
})

comparison_results
# Out:
#      Model  ROC-AUC  PR-AUC
# 0  XGBoost   0.8535  0.6701
# 1   BG/NBD   0.6139  0.2959

# %%
fig, ax = plt.subplots(
    figsize=(8, 5)
)

comparison_long = comparison_results.melt(
    id_vars="Model",
    var_name="Metric",
    value_name="Value"
)

sns.barplot(
    data=comparison_long,
    x="Metric",
    y="Value",
    hue="Model",
    ax=ax
)

ax.set_title(
    "XGBoost vs BG/NBD"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# The machine learning approach substantially outperformed the BG/NBD benchmark across all evaluation metrics.
#
# While BG/NBD provides an elegant probabilistic framework for modeling customer activity in non-contractual settings, its effectiveness depends on the presence of repeated purchase behavior. In the AdventureWorks dataset, where most customers completed only a single purchase during the calibration period, the model exhibited limited discriminatory power.
#
# In contrast, the XGBoost classifier successfully leveraged the combined information contained in the RFM variables and achieved substantially higher predictive accuracy, ranking performance, and customer separation capability.

# %% [markdown]
# ## Business Interpretation

# %% [markdown]
# From a business perspective, the primary objective of a churn model is not simply to classify customers as active or inactive, but to prioritize retention efforts toward those customers most likely to disengage in the future.
#
# The predicted churn probabilities generated by the selected XGBoost model can therefore be interpreted as customer risk scores. Customers with higher scores represent the most attractive targets for retention campaigns, loyalty programs, personalized offers, or proactive engagement strategies.
#
# To illustrate the practical usefulness of the model, customers are ranked according to their predicted probability of churn and grouped into risk segments.

# %%
model_data["churn_probability"] = (
    best_pipeline.predict_proba(
        X
    )[:, 1]
)

# %%
model_data["risk_decile"] = pd.qcut(
    model_data["churn_probability"],
    q=10,
    labels=False
) + 1

# %%
risk_summary = (
    model_data
    .groupby("risk_decile")
    .agg(
        customers=("customerid", "count"),
        observed_churn_rate=("churn", "mean"),
        average_probability=("churn_probability", "mean")
    )
    .sort_index(
        ascending=False
    )
)

risk_summary
# Out:
#              customers  observed_churn_rate  average_probability
# risk_decile
# 10                 624               0.7869               0.9051
# 9                  619               0.2779               0.6273
# 8                  630               0.1698               0.4828
# 7                  614               0.1564               0.3804
# 6                  633               0.0964               0.2845
# 5                  584               0.0497               0.1709
# 4                  630               0.0365               0.1252
# 3                  645               0.0248               0.1028
# 2                  634               0.0284               0.0804
# 1                  630               0.0048               0.0326

# %% [markdown]
# ### Churn Risk Segmentation

# %%
fig, ax = plt.subplots(
    figsize=(8, 5)
)

sns.barplot(
    data=risk_summary.reset_index(),
    x="risk_decile",
    y="observed_churn_rate",
    ax=ax
)

ax.set_title(
    "Observed Churn Rate by Predicted Risk Decile"
)

ax.set_xlabel(
    "Risk Decile"
)

ax.set_ylabel(
    "Observed Churn Rate"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# The observed churn rate increases substantially across the risk spectrum, indicating that the model successfully ranks customers according to future inactivity risk. This ranking capability is particularly valuable for customer retention programs because it allows organizations to focus limited resources on the customers most likely to disengage.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# This study evaluated customer churn prediction in a non-contractual retail environment using transaction data from the AdventureWorks database.
#
# Several classification algorithms and class-balancing strategies were compared using a temporally separated calibration and validation framework. Among all evaluated alternatives, XGBoost trained on the original dataset achieved the strongest overall performance and substantially outperformed both simpler machine learning models and the BG/NBD probabilistic benchmark.
#
# Key findings include:
#
# - Recency, Frequency, and Monetary variables all contributed meaningfully to churn prediction.
# - XGBoost provided the best balance between precision and recall while maintaining strong ranking performance.
# - Class-balancing strategies increased recall but did not materially improve overall model performance.
# - The selected model achieved strong customer separation, as demonstrated by the ROC, Precision-Recall, and KS analyses.
# - The BG/NBD benchmark exhibited limited predictive power in this dataset due to the large proportion of customers with only a single observed purchase.
# - The resulting churn probabilities can be used to prioritize customer retention initiatives and support data-driven customer relationship management strategies.
#
# Overall, the results demonstrate that machine learning models built from relatively simple transactional features can provide effective customer churn predictions in non-contractual retail settings.
